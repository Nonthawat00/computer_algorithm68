# %%
running = 10

for i in range(running):
    print("Round is :", i)
# Out:
# Round is : 0
# Round is : 1
# Round is : 2
# Round is : 3
# Round is : 4
# Round is : 5
# Round is : 6
# Round is : 7
# Round is : 8
# Round is : 9

# %%
check = True

while(check):
    print("check")
    check = False
# Out:
# check

# %%
running_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
running_int = int(running_str)

for i in range(running_int):
    print("รอบที่ : ", i+1)
# Out:
# รอบที่ :  1
# รอบที่ :  2
# รอบที่ :  3
# รอบที่ :  4
# รอบที่ :  5
# รอบที่ :  6
# รอบที่ :  7
# รอบที่ :  8
# รอบที่ :  9
# รอบที่ :  10

# %%
state = input("สั่งให้เริ่มวิ่ง ด้วยคำสั่ง 1 ")
state_running = True
if(state == '1'):
    state_running = True
else:
    state_running = False
i = 1
while(state):
    print("round : ",i)
    i = i +1
    interup = input("ต้องการหยุดหรือไม่ 1 หรือ 0")
    if(interup == '1'):
        state = True
    elif(interup == '0'):
        state = False
# Out:
# round :  1
# round :  2
# round :  3
# round :  4
# round :  5
# round :  6
# round :  7
# round :  8

# %%
Q = "Press Q = Exit"
M = "Press M = Main"
S = "Press S = start In Program"
state = True
while(state):
    print(Q)
    print(M)
    print(S)

    inp = input("Menu Selected : ")
    if(inp == 'Q'):
        state = False
    elif(inp == 'M'):
        print("Home Menu")
    elif(inp == 'S'):
        running_str = input("จำนวนรอบ : ")
        running_int = int(running_str)
        for i in range(running_int):
            print("รอบที่ : ", i+1)
        
    else:
        print("Home Menu")
# Out:
# Press Q = Exit
# Press M = Main
# Press S = start In Program
# รอบที่ :  1
# รอบที่ :  2
# รอบที่ :  3
# รอบที่ :  4
# รอบที่ :  5
# รอบที่ :  6
# รอบที่ :  7
# รอบที่ :  8
# รอบที่ :  9
# รอบที่ :  10
# Press Q = Exit
# Press M = Main
# Press S = start In Program
